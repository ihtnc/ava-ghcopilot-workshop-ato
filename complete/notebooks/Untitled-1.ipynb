# %% [markdown]
# # Install Required Packages
# Install the necessary packages, including pandas and matplotlib, using pip.

# %%
# Import the required module for the installation
import sys

# Install pandas
# !{sys.executable} -m pip install pandas

# Install matplotlib
# !{sys.executable} -m pip install matplotlib

# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including pandas and matplotlib.

# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the CSV File
# Use pandas to load the CSV file from the specified path.

# %%
csv_file_path = r'C:\Projects\ghcpdemo\complete\csv\usage.csv'
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
#   breakdown_language breakdown_editor  breakdown_suggestions_count  \
# 0  polyglot-notebook           vscode                           11
# 1             python           vscode                           15
# 2         powershell           vscode                          155
# 3               dart           vscode                          195
# 4               json           vscode                            1
#
#    breakdown_acceptances_count  breakdown_lines_suggested  \
# 0                            3                         12
# 1                            2                         23
# 2                           18                        238
# 3                           31                        297
# 4                            0                          2
#
#    breakdown_lines_accepted  breakdown_active_users         day  \
# 0                         3                       2  10/03/2024
# 1                         2                       2  10/03/2024
# ...

# %% [markdown]
# # Analyze the CSV File
# Use pandas functions to analyze the data in the CSV file, such as describe(), head(), tail(), etc.

# %%
# Display the last few rows of the DataFrame
df.tail()

# Display a summary of the DataFrame
df.describe()

# Plot a histogram for each numerical attribute
df.hist(bins=50, figsize=(20,15))
plt.show()
